# %% [markdown]
# ## Домашнее задание к лекции Работа с файловой системой и модули##

# %% [markdown]
# #### 1 Переведите содержимое файла purchase_log.txt в словарь purchases вида:{‘1840e0b9d4’: ‘Продукты’, …} ####

# %%
import json
result = {}
with open('purchase_log.txt','r', encoding='utf-8') as f:
    next(f)
    for line in f:
        line = line.strip()
        dict_ = json.loads(line)
        result[dict_['user_id']] = dict_['category']

# %% [markdown]
# #### 2. Для каждого user_id в файле visit_log.csv определите третий столбец с категорией покупки (если покупка была, сам файл visit_log.csv изменять не надо). Запишите в файл funnel.csv визиты из файла visit_log.csv, в которых были покупки с указанием категории. ####
# #### Учтите условия на данные:
# ##### содержимое purchase_log.txt помещается в оперативную память компьютера
# ##### содержимое visit_log.csv - нет; используйте только построчную обработку этого файла

# %%
with open('visit_log.csv', 'r') as f, open('funnel.csv', 'w') as new_f:
    for row in f:
        line_list=row.strip().split(',')
        if line_list[0] in result.keys():
            line_list.append(result[line_list[0]])
            add_line=','.join(line_list)
        elif line_list[0]=='user_id':
            line_list.append('category')
            add_line=','.join(line_list)
        else:
            add_line=','.join(line_list)
        new_f.write(add_line+'\n')
new_f.close()

# %%
i = 0
fr = open('funnel.csv', 'r') 
for i, line in enumerate(fr):
    print(i, line)
    if i > 100:
        break
# Out:
# 0 user_id,source,category
#
# 1 6450655ae8,other
#
# 2 b4ea53e670,other
#
# 3 0e37347152,other
#
# 4 96064ae9e0,other
#
# 5 e1bd168161,context
#
# 6 71bcf169b4,other
#
# 7 e0aee73c5d,other
#
# 8 1f8845e157,context
#
# 9 78d22c5c78,other
#
# 10 dd85040770,other
#
# 11 2301051b25,other
#
# 12 86835b81ac,context
#
# 13 90d9a575a2,other
#
# 14 1b75c4f23f,other
#
# 15 d94b908660,None
#
# 16 f697206af5,other
#
# 17 8a9a2de36e,other
#
# 18 dd3d43c266,context
#
# 19 f6401d302f,context
#
# 20 b18d58560b,email
#
# 21 ed79586589,other
#
# 22 1840e0b9d4,other,Продукты
#
# 23 b4afdc5ccc,other
#
# 24 470248aabf,other
#
# 25 948d9be43c,other
#
# 26 03592d16ac,other
#
# 27 8554e1a9f9,context
#
# 28 ceda3a4603,other
#
# 29 282d7418ae,context
#
# 30 6074c89112,context
#
# 31 60d796c3bd,other
#
# 32 cb9dd569e7,context
#
# 33 cc113dcb65,other
#
# 34 c0075c117c,other
#
# 35 8e3cd5cdcb,other
#
# 36 cddb2fc63e,other
#
# 37 73ce7c32ef,other
#
# 38 f1708b0dba,other
#
# 39 2ca3ddb1f8,other
#
# 40 3b8889be65,other
#
# 41 4d9e8e4506,other
#
# 42 9e7e01d962,email
#
# 43 da9fe887e0,other
#
# 44 892de9fb9c,context
#
# 45 37fe632faf,other
#
# 46 36e5386eab,other
#
# 47 86a94effc6,other
#
# 48 bf9d1ad797,other
#
# 49 c7d2c1423b,other
#
# 50 423bb91bd9,context
#
# 51 9d653ee784,context
#
# 52 e977795a7e,other
#
# 53 401a3ab75f,other
#
# 54 4111731cef,context
#
# 55 19019ca1fa,other
#
# 56 983bd13cab,other
#
# 57 fe653373f2,other
#
# 58 2abbac2d31,other
#
# 59 73e7ef925b,other
#
# 60 d09edf5601,context
#
# 61 a913944688,other
#
# 62 23ebe451aa,context
#
# 63 55a843d5ec,other
#
# 64 4ef5b2f5df,other
#
# 65 1ba32f4175,context
#
# 66 14c73d53c1,context
#
# 67 04d2e574e5,other
#
# 68 563649baca,context
#
# 69 8425f97879,other
#
# 70 ae35a7ee31,other
#
# 71 46ba5c1ed2,other
#
# 72 2db22b2d26,other
#
# 73 afe4346288,other
#
# 74 fe9328f2cc,other
#
# 75 c17571ba85,other
#
# 76 e3505d2025,context
#
# 77 7a84ac6499,context
#
# 78 be72c452ac,context
#
# 79 4e4f90fcfb,context,Электроника
#
# 80 66078e430a,other
#
# 81 4f352f9eed,other
#
# 82 a38a235471,other
#
# 83 5087ae3e47,context
#
# 84 188b23409c,other
#
# 85 c1a03154ba,other
#
# 86 3bbd519097,context
#
# 87 a9e40d48d8,email
#
# 88 562c05721b,other
#
# 89 f625b6856e,email
#
# 90 282c4ff5ac,context
#
# 91 52f1cd497a,other
#
# 92 554e8d80a0,other
#
# 93 cf16107d36,context
#
# 94 62afb48d01,other
#
# 95 afea8d72fc,other,Электроника
#
# 96 7971d6e2ff,other
#
# 97 13a54fb297,other
#
# 98 93cc83514a,other
#
# 99 5c1c7468f6,other
#
# 100 a558add052,context
#
# 101 66fd6fcb97,other
